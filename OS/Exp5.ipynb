# %%
import psutil
net_io = psutil.net_io_counters()
print(f" bytes sent:{net_io.bytes_sent/(1024**2):.2f}MB")
print(f" bytes received:{net_io.bytes_recv/(1024**2):.2f}MB")
# Out:
#  bytes sent:15.83MB
#  bytes received:673.15MB
